# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.6-py3-none-any.whl (1.0 MB)
#                                               0.0/1.0 MB ? eta -:--:--
#      -                                        0.0/1.0 MB 1.3 MB/s eta 0:00:01
#      -                                        0.0/1.0 MB 1.3 MB/s eta 0:00:01
#      -                                        0.0/1.0 MB 1.3 MB/s eta 0:00:01
#      -                                        0.0/1.0 MB 1.3 MB/s eta 0:00:01
#      -----                                    0.1/1.0 MB 607.9 kB/s eta 0:00:02
#      ------                                   0.2/1.0 MB 654.6 kB/s eta 0:00:02
#      ------                                   0.2/1.0 MB 654.6 kB/s eta 0:00:02
#      ------                                   0.2/1.0 MB 654.6 kB/s eta 0:00:02
#      ------                                   0.2/1.0 MB 654.6 kB/s eta 0:00:02
#      --------                                 0.2/1.0 MB 461.0 kB/s eta 0:00:02
#      --------                                 0.2/1.0 MB 461.0 kB/s eta 0:00:02
#      --------                                 0.2/1.0 MB 461.0 kB/s eta 0:00:02
#      ------------------                       0.5/1.0 MB 758.5 kB/s eta 0:00:01
#      -----------------------------------      0.9/1.0 MB 1.4 MB/s eta 0:00:01
#      -----------------------------------      0.9/1.0 MB 1.4 MB/s eta 0:00:01
#      -----------------------------------      0.9/1.0 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  1.0/1.0 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (3.8.3)
# Collecting langchain-core<0.4.0,>=0.3.14 (from langchain)
#   Downloading langchain_core-0.3.14-py3-none-any.whl (408 kB)
#                                               0.0/408.7 kB ? eta -:--:--
#      ------------------------------------- 408.7/408.7 kB 12.9 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.1-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.138-py3-none-any.whl (299 kB)
#                                               0.0/299.0 kB ? eta -:--:--
#      ------------------------------------- 299.0/299.0 kB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (1.24.3)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.14->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<25,>=23.2 (from langchain-core<0.4.0,>=0.3.14->langchain)
#   Downloading packaging-24.1-py3-none-any.whl (53 kB)
#                                               0.0/54.0 kB ? eta -:--:--
#      ---------------------------------------- 54.0/54.0 kB ? eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.14->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.10-cp311-none-win_amd64.whl (139 kB)
#                                               0.0/139.3 kB ? eta -:--:--
#      -------------------------------------- 139.3/139.3 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Collecting pydantic-core==2.23.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.23.4-cp311-none-win_amd64.whl (1.9 MB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\asus\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.5.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.14->langchain) (2.1)
# Installing collected packages: pydantic-core, packaging, orjson, jsonpatch, pydantic, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
# Successfully installed jsonpatch-1.33 langchain-0.3.6 langchain-core-0.3.14 langchain-text-splitters-0.3.1 langsmith-0.1.138 orjson-3.10.10 packaging-24.1 pydantic-2.9.2 pydantic-core-2.23.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# huggingface-hub 0.25.1 requires fsspec>=2023.5.0, but you have fsspec 2023.3.0 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.

# %%
pip install -U langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.2.0-py3-none-any.whl (14 kB)
# Collecting groq<1,>=0.4.1 (from langchain-groq)
#   Downloading groq-0.11.0-py3-none-any.whl (106 kB)
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#                                               0.0/106.5 kB ? eta -:--:--
#      ---------------                          41.0/106.5 kB ? eta -:--:--
#      ----------------------                  61.4/106.5 kB 1.1 MB/s eta 0:00:01
#      ----------------------                  61.4/106.5 kB 1.1 MB/s eta 0:00:01
#      ----------------------                  61.4/106.5 kB 1.1 MB/s eta 0:00:01
#      ----------------------                  61.4/106.5 kB 1.1 MB/s eta 0:00:01
#      ----------------------                  61.4/106.5 kB 1.1 MB/s eta 0:00:01
#      ----------------------                  61.4/106.5 kB 1.1 MB/s eta 0:00:01
#      ----------------------                  61.4/106.5 kB 1.1 MB/s eta 0:00:01
#      ----------------------                  61.4/106.5 kB 1.1 MB/s eta 0:00:01
#      ------------------------------------ 106.5/106.5 kB 212.5 kB/s eta 0:00:00
# Requirement already satisfied: langchain-core<0.4,>=0.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain-groq) (0.3.14)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (3.5.0)
# Collecting distro<2,>=1.7.0 (from groq<1,>=0.4.1->langchain-groq)
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\asus\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (6.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (0.1.138)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (8.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.4)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-groq) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (3.10.10)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (2.31.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (1.26.16)
# Installing collected packages: distro, groq, langchain-groq
# Successfully installed distro-1.9.0 groq-0.11.0 langchain-groq-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key='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',
    model="llama-3.1-70b-versatile",
    temperature=0.0,
    max_retries=2,
    )
response=llm.invoke("The NITI Aayog of India..")
print(response.content)
# Out:
# The NITI Aayog (National Institution for Transforming India) is a policy think tank of the Government of India. It was established on January 1, 2015, by the Government of India, replacing the Planning Commission of India, which was set up in 1950.
#
# The main objectives of NITI Aayog are:
#
# 1. To create a platform for the government to engage with experts, academics, and industry leaders to develop policies and programs for the country's development.
# 2. To provide a framework for the government to engage with states and other stakeholders to develop policies and programs that are tailored to the needs of different regions and communities.
# 3. To promote a culture of innovation and entrepreneurship in the country.
# 4. To develop a long-term vision for the country's development and to identify key areas for focus and investment.
#
# The NITI Aayog is headed by the Prime Minister of India, and its members include:
#
# 1. The Prime Minister (Chairperson)
# 2. A Vice-Chairperson (appointed by the Prime Minister)
# 3. A CEO (appointed by the Prime Minister)
# 4. Full-time members (appointed by the Prime Minister)
# 5. Part-time members (appointed by the Prime Minister)
# 6. Ex-officio members (including the Union Ministers of Finance, Home, Defence, and other key ministries)
#
# The NITI Aayog has several key initiatives and programs, including:
#
# 1. The Three-Year Action Agenda: a comprehensive plan for the country's development over a three-year period.
# 2. The Seven-Year Strategy: a long-term plan for the country's development over a seven-year period.
# 3. The 15-Year Vision: a long-term plan for the country's development over a 15-year period.
# 4. The Atal Innovation Mission: a program to promote innovation and entrepreneurship in the country.
# 5. The Digital India initiative: a program to promote the use of technology and digital services in the country.
#
# Overall, the NITI Aayog plays a key role in shaping the country's development policies and programs, and in promoting a culture of innovation and entrepreneurship in India.
